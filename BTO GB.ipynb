# %%
from aimsgb import GrainBoundary, Grain

s_input = Grain.from_mp_id("mp-2998")
gb = GrainBoundary([1, 1, 0], 9, [-1, 1, -4], s_input, uc_a=3, uc_b=3)
structure = Grain.stack_grains(gb.grain_a, gb.grain_b, direction=gb.direction)
# Out:
# Retrieving MaterialsDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
structure.to(filename="BTO_[110]9[-11-4]_POSCAR")
# Out:
# 'Ba108 Ti108 O324\n1.0\n 102.0189190110421151    0.0000000000000000   -0.0000000000000164\n  -0.0000000000000007   12.0230449070048433    0.0000000000000007\n   0.0000000000000000    0.0000000000000000    5.6677177228356737\nBa Ti O\n108 108 324\ndirect\n   0.1296296296296296    0.6111111111111112    0.4999999999999999 Ba\n   0.2962962962962962    0.6111111111111112    0.4999999999999999 Ba\n   0.4629629629629629    0.6111111111111112    0.4999999999999999 Ba\n   0.0925925925925926    0.7222222222222224    0.4999999999999999 Ba\n   0.2592592592592592    0.7222222222222224    0.4999999999999999 Ba\n   0.4259259259259259    0.7222222222222224    0.4999999999999999 Ba\n   0.0555555555555556    0.8333333333333333    0.4999999999999997 Ba\n   0.2222222222222222    0.8333333333333333    0.4999999999999997 Ba\n   0.3888888888888889    0.8333333333333333    0.4999999999999997 Ba\n   0.0185185185185185    0.9444444444444444    0.4999999999999999 Ba\n   0.1851851851851852    0.9444444444444444
# ...

# %%
from aimsgb import GBInformation

print(GBInformation([0, 0, 1], 200).__str__())
# Out:
# Grain boundary information for rotation axis: 001
# Show the sigma values up to 200 (Note: * means twist GB, Theta is the rotation angle)
# |  Sigma  |  Theta  | GB plane    | CSL matrix   |
# |---------+---------+-------------+--------------|
# |    5    |  53.13  | (2 -1 0)    | 2  1  0      |
# |         |         | (1 2 0)     | -1  2  0     |
# |         |         | (0 0 1)*    | 0  0  1      |
# |    5    |  36.87  | (3 -1 0)    | 3  1  0      |
# |         |         | (1 3 0)     | -1  3  0     |
# |         |         | (0 0 1)*    | 0  0  1      |
# |   13    |  67.38  | (3 -2 0)    | 3  2  0      |
# |         |         | (2 3 0)     | -2  3  0     |
# |         |         | (0 0 1)*    | 0  0  1      |
# |   13    |  22.62  | (5 -1 0)    | 5  1  0      |
# |         |         | (1 5 0)     | -1  5  0     |
# |         |         | (0 0 1)*    | 0  0  1      |
# |   17    |  28.07  | (4 1 0)     | 4 -1  0      |
# |         |         | (-1 4 0)    | 1  4  0      |
# ...
